# %% [markdown]
# <a href="https://colab.research.google.com/github/totibakar/IF433_Lab_Works/blob/main/Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello, World!')
# Out:
# Hello, World!
